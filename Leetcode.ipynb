# %% [markdown]
# <a href="https://colab.research.google.com/github/nehakanjamala/leetcode_practice/blob/main/Leetcode.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Hashmap**

# %% [markdown]
# Two Sum
#
#  *You are given an array of integers nums and an integer target, return indices of the two numbers such that they add up to target.*
#
#  *You may assume that each input would have exactly one solution, and you may not use the same element twice. You can return the answer in any order.*

# %%
nums = [] # ex: 1, 2, 3, 7
nums = input().split()
for i in range(len(nums)):
  nums[i] = int(nums[i])
print(f"Nums: {nums}")
target = int(input()) # target: 9
print(f"Target: {target}")
seen = {} # index : num 0:1 1:2

for i,num in enumerate(nums): #0:1, 1:2 7
  needed = target - num #9-7=2
  if needed in seen:
    print(seen[needed], i)
  else:
    seen[num] = i #seen[2]
# Out:
# 1 2 3 7
# Nums: [1, 2, 3, 7]
# 9
# Target: 9
# 1 3

# %% [markdown]
# Frequency Count
